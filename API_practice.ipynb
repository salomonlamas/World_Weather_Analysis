# %%
# Dependencies
import random
import timeit
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy
import requests
from datetime import datetime
# API source
from config import weather_api_key

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
for coordinate in coordinates:
    print(coordinate[0],coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
#lat_lngs = zip(*lat_lngs)
#coordinates = list(lat_lngs)
lats = np.random.uniform(-90,90,size=1500)
lngs = np.random.uniform(-180,180,size=1500)
lat_lngs = zip(lats,lngs)

for lat_lng in lat_lngs:
    print(lat_lng[0],lat_lng[1])
    break
# Out:
# 79.52228458143273 70.7047974891612

# %%
# Create list for holding the cities
cities = []

# Identify the nearest city for each lat and long combo
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0],lat_lng[1]).city_name
    
    # Filter out dupes
    if city not in cities:
        cities.append(city)
# confirmation
print(len(cities))
# Out:
# 615

# %%
# URL for Weahter Map API Call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c777755f1537ae28f437f017b5d96844

# %%
query_url = url + "appid" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c777755f1537ae28f437f017b5d96844&q=Boston

# %%
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 67.24,
#   'feels_like': 66.7,
#   'temp_min': 64,
#   'temp_max': 71.01,
#   'pressure': 1013,
#   'humidity': 83},
#  'wind': {'speed': 8.05, 'deg': 130},
#  'clouds': {'all': 78},
#  'dt': 1592873520,
#  'sys': {'type': 1,
#   'id': 4967,
#   'country': 'US',
#   'sunrise': 1592816870,
#   'sunset': 1592871887},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
    
boston_data = city_weather.json()
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 67.24,
#   'feels_like': 66.7,
#   'temp_min': 64,
#   'temp_max': 71.01,
#   'pressure': 1013,
#   'humidity': 83},
#  'wind': {'speed': 8.05, 'deg': 130},
#  'clouds': {'all': 78},
#  'dt': 1592873520,
#  'sys': {'type': 1,
#   'id': 4967,
#   'country': 'US',
#   'sunrise': 1592816870,
#   'sunset': 1592871887},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.36 -71.06 71.01 83 78 8.05

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2020-06-23 00:52:00'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 16 of Set 13 | kavieng
# Processing Record 17 of Set 13 | cherskiy
# Processing Record 18 of Set 13 | rikitea
# Processing Record 19 of Set 13 | ribeira grande
# Processing Record 20 of Set 13 | manokwari
# Processing Record 21 of Set 13 | portland
# Processing Record 22 of Set 13 | ushuaia
# Processing Record 23 of Set 13 | dangriga
# Processing Record 24 of Set 13 | hilo
# Processing Record 25 of Set 13 | ukiah
# Processing Record 26 of Set 13 | sambava
# Processing Record 27 of Set 13 | faanui
# Processing Record 28 of Set 13 | pangnirtung
# Processing Record 29 of Set 13 | butaritari
# Processing Record 30 of Set 13 | tutoia
# Processing Record 31 of Set 13 | beruni
# City not found. Skipping...
# Processing Record 32 of Set 13 | puerto ayora
# Processing Record 33 of Set 13 | ndjole
# Processing Record 34 of Set 13 | tukrah
# Processing Record 35 of Set 13 | coahuayana
# Processing Record 36 of Set 13 | morondava
# Processing Record 37 of Set 13 | georgetown
# Processing Record 38 of Set 13 | hithadhoo
# Processing Record 39 of Set 13 | henties bay
# Processing Record 40 of Set 13 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 13 | san quintin
# Processing Record 42 of Set 13 | souillac
# Processing Record 43 of Set 13 | saint george
# Processing Record 44 of Set 13 | tawang
# Processing Record 45 of Set 13 | qaanaaq
# Processing Record 46 of Set 13 | torbay
# Processing Record 47 of Set 13 | rorvik
# Processing Record 48 of Set 13 | sorland
# Processing Record 49 of Set 13 | codrington
# Processing Record 50 of Set 13 | new norfolk
# Processing Record 51 of Set 13 | pitlochry
# Processing Record 52 of Set 13 | castanos
# Processing Record 53 of Set 13 | jelgava
# Processing Record 54 of Set 13 | bethel
# Processing Record 55 of Set 13 | rocha
# Processing Record 56 of Set 13 | saint-philippe
# Processing Record 57 of Set 13 | dikson
# Processing Record 58 of Set 13 | seoul
# Processing Record 59 of Set 13 | vaini
# Processing Record 60 of Set 13 | nizhniy odes
# Processing Record 61 of Set 13 | lagos
# Processing Record 62 of Set 13 | lai
# Processing Record 63 of Set 13 | busselton
# Processing Record 64 of Set 13 | nola
# Processing Record 65 of Set 13 | tura
# Processing Record 1 of Set 14 | norman wells
# Processing Record 2 of Set 14 | jamestown
# Processing Record 3 of Set 14 | albany
# Processing Record 4 of Set 14 | atuona
# Processing Record 5 of Set 14 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 14 | bluff
# Processing Record 7 of Set 14 | severo-kurilsk
# Processing Record 8 of Set 14 | ljubinje
# Processing Record 9 of Set 14 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 14 | san policarpo
# Processing Record 11 of Set 14 | srednekolymsk
# Processing Record 12 of Set 14 | cape town
# Processing Record 13 of Set 14 | khatanga
# Processing Record 14 of Set 14 | along
# Processing Record 15 of Set 14 | avarua
# Processing Record 16 of Set 14 | kapit
# Processing Record 17 of Set 14 | tasiilaq
# Processing Record 18 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 14 | saldanha
# Processing Record 20 of Set 14 | milyutinskaya
# Processing Record 21 of Set 14 | sibu
# Processing Record 22 of Set 14 | hamilton
# Processing Record 23 of Set 14 | lagoa
# Processing Record 24 of Set 14 | rio grande
# Processing Record 25 of Set 14 | chokurdakh
# Processing Record 26 of Set 14 | tartus
# Processing Record 27 of Set 14 | bredasdorp
# Processing Record 28 of Set 14 | methven
# Processing Record 29 of Set 14 | constitucion
# Processing Record 30 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 14 | ponta do sol
# Processing Record 32 of Set 14 | vardo
# Processing Record 33 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 34 of Set 14 | byron bay
# Processing Record 35 of Set 14 | gizo
# Processing Record 36 of Set 14 | la uribe
# City not found. Skipping...
# Processing Record 37 of Set 14 | te anau
# Processing Record 38 of Set 14 | tiznit
# Processing Record 39 of Set 14 | castro
# Processing Record 40 of Set 14 | lompoc
# Processing Record 41 of Set 14 | upernavik
# Processing Record 42 of Set 14 | mataura
# Processing Record 43 of Set 14 | morgan city
# Processing Record 44 of Set 14 | bagepalli
# Processing Record 45 of Set 14 | kapaa
# Processing Record 46 of Set 14 | saint-joseph
# Processing Record 47 of Set 14 | bambous virieux
# Processing Record 48 of Set 14 | kantemirovka
# Processing Record 49 of Set 14 | xuanhua
# Processing Record 50 of Set 14 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 15 | esperance
# Processing Record 2 of Set 15 | nikolskoye
# Processing Record 3 of Set 15 | palafrugell
# Processing Record 4 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 15 | kawalu
# Processing Record 6 of Set 15 | yanchukan
# City not found. Skipping...
# Processing Record 7 of Set 15 | tezu
# Processing Record 8 of Set 15 | mahajanga
# Processing Record 9 of Set 15 | punta arenas
# Processing Record 10 of Set 15 | saskylakh
# Processing Record 11 of Set 15 | grenaa
# Processing Record 12 of Set 15 | pangkalanbuun
# Processing Record 13 of Set 15 | asau
# Processing Record 14 of Set 15 | oranjemund
# Processing Record 15 of Set 15 | pisco
# Processing Record 16 of Set 15 | indianola
# Processing Record 17 of Set 15 | shulan
# Processing Record 18 of Set 15 | yellowknife
# Processing Record 19 of Set 15 | marawi
# Processing Record 20 of Set 15 | naduvattam
# Processing Record 21 of Set 15 | nchelenge
# Processing Record 22 of Set 15 | lebu
# Processing Record 23 of Set 15 | kodiak
# Processing Record 24 of Set 15 | cabo san lucas
# Processing Record 25 of Set 15 | gudari
# Processing Record 26 of Set 15 | jacareacanga
# Processing Record 27 of Set 15 | gondanglegi
# Processing Record 28 of Set 15 | cayenne
# Processing Record 29 of Set 15 | sitka
# Processing Record 30 of Set 15 | kieta
# Processing Record 31 of Set 15 | port alfred
# Processing Record 32 of Set 15 | hobart
# Processing Record 33 of Set 15 | katangli
# Processing Record 34 of Set 15 | mahebourg
# Processing Record 35 of Set 15 | barrow
# Processing Record 36 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 37 of Set 15 | vao
# Processing Record 38 of Set 15 | zhitikara
# City not found. Skipping...
# Processing Record 39 of Set 15 | iqaluit
# Processing Record 40 of Set 15 | sur
# Processing Record 41 of Set 15 | aksarka
# Processing Record 42 of Set 15 | shintomi
# Processing Record 43 of Set 15 | thinadhoo
# Processing Record 44 of Set 15 | east london
# Processing Record 45 of Set 15 | fortuna
# Processing Record 46 of Set 15 | hermanus
# Processing Record 47 of Set 15 | shevchenkove
# Processing Record 48 of Set 15 | changping
# Processing Record 49 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 50 of Set 15 | adrar
# Processing Record 1 of Set 16 | tucumcari
# Processing Record 2 of Set 16 | cabedelo
# Processing Record 3 of Set 16 | waingapu
# Processing Record 4 of Set 16 | menongue
# Processing Record 5 of Set 16 | araouane
# Processing Record 6 of Set 16 | turukhansk
# Processing Record 7 of Set 16 | rabo de peixe
# Processing Record 8 of Set 16 | yulara
# Processing Record 9 of Set 16 | san patricio
# Processing Record 10 of Set 16 | meulaboh
# Processing Record 11 of Set 16 | svetlaya
# Processing Record 12 of Set 16 | arraial do cabo
# Processing Record 13 of Set 16 | katsuura
# Processing Record 14 of Set 16 | mount isa
# Processing Record 15 of Set 16 | vzmorye
# Processing Record 16 of Set 16 | clyde river
# Processing Record 17 of Set 16 | mar del plata
# Processing Record 18 of Set 16 | guerrero negro
# Processing Record 19 of Set 16 | mehamn
# Processing Record 20 of Set 16 | los llanos de aridane
# Processing Record 21 of Set 16 | acarau
# Processing Record 22 of Set 16 | tiksi
# Processing Record 23 of Set 16 | vostok
# Processing Record 24 of Set 16 | tuktoyaktuk
# Processing Record 25 of Set 16 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 16 | panji
# Processing Record 27 of Set 16 | rio novo do sul
# Processing Record 28 of Set 16 | jeremie
# Processing Record 29 of Set 16 | soddy-daisy
# Processing Record 30 of Set 16 | changli
# Processing Record 31 of Set 16 | abuyog
# Processing Record 32 of Set 16 | fort nelson
# Processing Record 33 of Set 16 | egvekinot
# Processing Record 34 of Set 16 | probolinggo
# Processing Record 35 of Set 16 | kannapolis
# Processing Record 36 of Set 16 | sao miguel do araguaia
# Processing Record 37 of Set 16 | boulder city
# Processing Record 38 of Set 16 | barra patuca
# Processing Record 39 of Set 16 | mae sai
# Processing Record 40 of Set 16 | itoman
# Processing Record 41 of Set 16 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 16 | port elizabeth
# Processing Record 43 of Set 16 | nizhnyaya tavda
# Processing Record 44 of Set 16 | zhanaozen
# Processing Record 45 of Set 16 | jalu
# Processing Record 46 of Set 16 | xichang
# Processing Record 47 of Set 16 | salalah
# Processing Record 48 of Set 16 | mackay
# Processing Record 49 of Set 16 | vernon
# Processing Record 50 of Set 16 | husavik
# Processing Record 1 of Set 17 | urucara
# Processing Record 2 of Set 17 | kristiansand
# Processing Record 3 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 17 | mecca
# Processing Record 5 of Set 17 | prado
# Processing Record 6 of Set 17 | najran
# Processing Record 7 of Set 17 | batesville
# Processing Record 8 of Set 17 | elizabeth city
# Processing Record 9 of Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 17 | bur gabo
# City not found. Skipping...
# Processing Record 11 of Set 17 | beibei
# Processing Record 12 of Set 17 | nisia floresta
# Processing Record 13 of Set 17 | vavozh
# Processing Record 14 of Set 17 | podlesnoye
# Processing Record 15 of Set 17 | tiarei
# Processing Record 16 of Set 17 | airai
# Processing Record 17 of Set 17 | planaltina
# Processing Record 18 of Set 17 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 17 | carnarvon
# Processing Record 20 of Set 17 | mitha tiwana
# Processing Record 21 of Set 17 | nanortalik
# Processing Record 22 of Set 17 | sataua
# City not found. Skipping...
# Processing Record 23 of Set 17 | necochea
# Processing Record 24 of Set 17 | sokoni
# Processing Record 25 of Set 17 | port blair
# Processing Record 26 of Set 17 | pemangkat
# Processing Record 27 of Set 17 | rio gallegos
# Processing Record 28 of Set 17 | grand-lahou
# Processing Record 29 of Set 17 | novikovo
# Processing Record 30 of Set 17 | camacupa
# Processing Record 31 of Set 17 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 17 | kahului
# Processing Record 33 of Set 17 | provideniya
# Processing Record 34 of Set 17 | severo-yeniseyskiy
# Processing Record 35 of Set 17 | jizan
# Processing Record 36 of Set 17 | bengkulu
# Processing Record 37 of Set 17 | luderitz
# Processing Record 38 of Set 17 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 17 | deputatskiy
# Processing Record 40 of Set 17 | presidencia roque saenz pena
# Processing Record 41 of Set 17 | rincon
# Processing Record 42 of Set 17 | praia da vitoria
# Processing Record 43 of Set 17 | ankazoabo
# Processing Record 44 of Set 17 | hasaki
# Processing Record 45 of Set 17 | omsukchan
# Processing Record 46 of Set 17 | puerto narino
# Processing Record 47 of Set 17 | tayoltita
# Processing Record 48 of Set 17 | zatoka
# Processing Record 49 of Set 17 | kamina
# Processing Record 50 of Set 17 | isparta
# Processing Record 1 of Set 18 | kesennuma
# City not found. Skipping...
# Processing Record 2 of Set 18 | huarmey
# Processing Record 3 of Set 18 | sangar
# Processing Record 4 of Set 18 | arlit
# Processing Record 5 of Set 18 | veselynove
# Processing Record 6 of Set 18 | klaksvik
# Processing Record 7 of Set 18 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 8 of Set 18 | karaton
# Processing Record 9 of Set 18 | solnechnyy
# Processing Record 10 of Set 18 | vila
# Processing Record 11 of Set 18 | sao filipe
# Processing Record 12 of Set 18 | takoradi
# Processing Record 13 of Set 18 | wanning
# Processing Record 14 of Set 18 | mamontovo
# Processing Record 15 of Set 18 | sawtell
# Processing Record 16 of Set 18 | avera
# Processing Record 17 of Set 18 | coihaique
# Processing Record 18 of Set 18 | port hedland
# Processing Record 19 of Set 18 | urengoy
# Processing Record 20 of Set 18 | maragogi
# Processing Record 21 of Set 18 | jaca
# Processing Record 22 of Set 18 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 18 | ossora
# Processing Record 24 of Set 18 | evanston
# Processing Record 25 of Set 18 | mackenzie
# Processing Record 26 of Set 18 | torbat-e jam
# Processing Record 27 of Set 18 | fort abbas
# Processing Record 28 of Set 18 | ewa beach
# Processing Record 29 of Set 18 | jiangyou
# Processing Record 30 of Set 18 | namibe
# Processing Record 31 of Set 18 | raudeberg
# Processing Record 32 of Set 18 | high level
# Processing Record 33 of Set 18 | chuy
# Processing Record 34 of Set 18 | sao joao da barra
# Processing Record 35 of Set 18 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 18 | dongzhen
# Processing Record 37 of Set 18 | van
# Processing Record 38 of Set 18 | cidreira
# Processing Record 39 of Set 18 | namatanai
# Processing Record 40 of Set 18 | rawlins
# Processing Record 41 of Set 18 | nizhniy tsasuchey
# Processing Record 42 of Set 18 | victoria
# Processing Record 43 of Set 18 | lincoln
# Processing Record 44 of Set 18 | pierre
# Processing Record 45 of Set 18 | barroualie
# City not found. Skipping...
# Processing Record 46 of Set 18 | geraldton
# Processing Record 47 of Set 18 | tuggurt
# City not found. Skipping...
# Processing Record 48 of Set 18 | camacha
# Processing Record 49 of Set 18 | bantou
# Processing Record 50 of Set 18 | rafai
# Processing Record 1 of Set 19 | ust-tsilma
# Processing Record 2 of Set 19 | kandrian
# Processing Record 3 of Set 19 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 19 | navalmoral de la mata
# Processing Record 5 of Set 19 | naze
# Processing Record 6 of Set 19 | bintulu
# Processing Record 7 of Set 19 | catuday
# Processing Record 8 of Set 19 | tuatapere
# Processing Record 9 of Set 19 | lokken verk
# City not found. Skipping...
# Processing Record 10 of Set 19 | amazar
# Processing Record 11 of Set 19 | kungurtug
# Processing Record 12 of Set 19 | lamar
# Processing Record 13 of Set 19 | lhokseumawe
# Processing Record 14 of Set 19 | narsaq
# Processing Record 15 of Set 19 | roma
# Processing Record 16 of Set 19 | fairbanks
# Processing Record 17 of Set 19 | mabaruma
# Processing Record 18 of Set 19 | igdir
# Processing Record 19 of Set 19 | jambi
# Processing Record 20 of Set 19 | coquimbo
# Processing Record 21 of Set 19 | aguimes
# Processing Record 22 of Set 19 | finnsnes
# Processing Record 23 of Set 19 | lieksa
# Processing Record 24 of Set 19 | muisne
# Processing Record 25 of Set 19 | mbandaka
# Processing Record 26 of Set 19 | ust-maya
# Processing Record 27 of Set 19 | chik
# Processing Record 28 of Set 19 | makubetsu
# Processing Record 29 of Set 19 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 19 | shebalino
# Processing Record 31 of Set 19 | thurso
# Processing Record 32 of Set 19 | carutapera
# Processing Record 33 of Set 19 | ouegoa
# Processing Record 34 of Set 19 | dingle
# Processing Record 35 of Set 19 | kerteh
# City not found. Skipping...
# Processing Record 36 of Set 19 | pandan
# Processing Record 37 of Set 19 | gusev
# Processing Record 38 of Set 19 | mpika
# Processing Record 39 of Set 19 | goderich
# Processing Record 40 of Set 19 | inhambane
# Processing Record 41 of Set 19 | lorengau
# Processing Record 42 of Set 19 | carinhanha
# Processing Record 43 of Set 19 | olafsvik
# Processing Record 44 of Set 19 | meadow lake
# Processing Record 45 of Set 19 | mercedes
# Processing Record 46 of Set 19 | progreso
# Processing Record 47 of Set 19 | mnogovershinnyy
# Processing Record 48 of Set 19 | balikpapan
# Processing Record 49 of Set 19 | esperantinopolis
# Processing Record 50 of Set 19 | zaozerne
# Processing Record 1 of Set 20 | srivardhan
# Processing Record 2 of Set 20 | jiddah
# City not found. Skipping...
# Processing Record 3 of Set 20 | itarema
# Processing Record 4 of Set 20 | bar harbor
# Processing Record 5 of Set 20 | torres
# Processing Record 6 of Set 20 | tres arroyos
# Processing Record 7 of Set 20 | beringovskiy
# Processing Record 8 of Set 20 | lar
# Processing Record 9 of Set 20 | limbang
# Processing Record 10 of Set 20 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 20 | solovetskiy
# City not found. Skipping...
# Processing Record 12 of Set 20 | mandalgovi
# Processing Record 13 of Set 20 | trofors
# Processing Record 14 of Set 20 | ilulissat
# Processing Record 15 of Set 20 | paamiut
# Processing Record 16 of Set 20 | caravelas
# Processing Record 17 of Set 20 | aklavik
# Processing Record 18 of Set 20 | columbio
# Processing Record 19 of Set 20 | bathsheba
# Processing Record 20 of Set 20 | gubkinskiy
# Processing Record 21 of Set 20 | santa rosa
# Processing Record 22 of Set 20 | vestmanna
# Processing Record 23 of Set 20 | pailon
# Processing Record 24 of Set 20 | erzin
# Processing Record 25 of Set 20 | idanre
# Processing Record 26 of Set 20 | san cristobal
# Processing Record 27 of Set 20 | ghogha
# Processing Record 28 of Set 20 | kovernino
# Processing Record 29 of Set 20 | beisfjord
# Processing Record 30 of Set 20 | udankudi
# Processing Record 31 of Set 20 | dicabisagan
# Processing Record 32 of Set 20 | gweta
# Processing Record 33 of Set 20 | mankono
# Processing Record 34 of Set 20 | padang
# Processing Record 35 of Set 20 | praya
# Processing Record 36 of Set 20 | petatlan
# Processing Record 37 of Set 20 | saryg-sep
# Processing Record 38 of Set 20 | tungkang
# City not found. Skipping...
# Processing Record 39 of Set 20 | kuzhithurai
# Processing Record 40 of Set 20 | longyearbyen
# Processing Record 41 of Set 20 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 20 | salinopolis
# Processing Record 43 of Set 20 | port lincoln
# Processing Record 44 of Set 20 | barawe
# City not found. Skipping...
# Processing Record 45 of Set 20 | magadan
# Processing Record 46 of Set 20 | timaru
# Processing Record 47 of Set 20 | chifeng
# Processing Record 48 of Set 20 | san vicente
# Processing Record 49 of Set 20 | neverkino
# Processing Record 50 of Set 20 | ust-nera
# Processing Record 1 of Set 21 | nabire
# Processing Record 2 of Set 21 | talnakh
# Processing Record 3 of Set 21 | mulchen
# Processing Record 4 of Set 21 | shepetivka
# Processing Record 5 of Set 21 | mezen
# Processing Record 6 of Set 21 | karratha
# Processing Record 7 of Set 21 | marathon
# Processing Record 8 of Set 21 | fort saint james
# Processing Record 9 of Set 21 | komsomolskiy
# Processing Record 10 of Set 21 | vila franca do campo
# Processing Record 11 of Set 21 | saquena
# Processing Record 12 of Set 21 | shimoda
# Processing Record 13 of Set 21 | poum
# Processing Record 14 of Set 21 | mount gambier
# Processing Record 15 of Set 21 | sand
# Processing Record 16 of Set 21 | parana
# Processing Record 17 of Set 21 | luena
# Processing Record 18 of Set 21 | bara
# Processing Record 19 of Set 21 | shipunovo
# Processing Record 20 of Set 21 | kununurra
# Processing Record 21 of Set 21 | jiaocheng
# Processing Record 22 of Set 21 | nome
# Processing Record 23 of Set 21 | alofi
# Processing Record 24 of Set 21 | huilong
# Processing Record 25 of Set 21 | talkha
# Processing Record 26 of Set 21 | brae
# Processing Record 27 of Set 21 | pontes e lacerda
# Processing Record 28 of Set 21 | waipawa
# Processing Record 29 of Set 21 | ketchikan
# Processing Record 30 of Set 21 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 21 | nianzishan
# Processing Record 32 of Set 21 | altay
# Processing Record 33 of Set 21 | cabuyaro
# Processing Record 34 of Set 21 | roebourne
# Processing Record 35 of Set 21 | chake chake
# Processing Record 36 of Set 21 | ancud
# Processing Record 37 of Set 21 | berdigestyakh
# Processing Record 38 of Set 21 | burnie
# Processing Record 39 of Set 21 | hanmer springs
# Processing Record 40 of Set 21 | maniitsoq
# Processing Record 41 of Set 21 | nao-me-toque
# City not found. Skipping...
# Processing Record 42 of Set 21 | roald
# Processing Record 43 of Set 21 | ternate
# Processing Record 44 of Set 21 | hunza
# City not found. Skipping...
# Processing Record 45 of Set 21 | duobao
# Processing Record 46 of Set 21 | bone
# Processing Record 47 of Set 21 | burica
# City not found. Skipping...
# Processing Record 48 of Set 21 | andros town
# Processing Record 49 of Set 21 | mareeba
# Processing Record 50 of Set 21 | malatya
# Processing Record 1 of Set 22 | alto araguaia
# Processing Record 2 of Set 22 | dalvik
# Processing Record 3 of Set 22 | svetlogorsk
# Processing Record 4 of Set 22 | port hardy
# Processing Record 5 of Set 22 | mangan
# Processing Record 6 of Set 22 | wanlaweyn
# Processing Record 7 of Set 22 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 22 | san luis
# Processing Record 9 of Set 22 | laguna
# Processing Record 10 of Set 22 | murray
# Processing Record 11 of Set 22 | lethem
# Processing Record 12 of Set 22 | sinnamary
# Processing Record 13 of Set 22 | ngunguru
# Processing Record 14 of Set 22 | kegayli
# City not found. Skipping...
# Processing Record 15 of Set 22 | luangwa
# Processing Record 16 of Set 22 | campbellton
# Processing Record 17 of Set 22 | murzzuschlag
# Processing Record 18 of Set 22 | south sioux city
# Processing Record 19 of Set 22 | teya
# Processing Record 20 of Set 22 | sinop
# Processing Record 21 of Set 22 | hailun
# Processing Record 22 of Set 22 | flinders
# Processing Record 23 of Set 22 | gonen
# Processing Record 24 of Set 22 | marienburg
# Processing Record 25 of Set 22 | naron
# Processing Record 26 of Set 22 | neftekumsk
# Processing Record 27 of Set 22 | kathu
# Processing Record 28 of Set 22 | sept-iles
# Processing Record 29 of Set 22 | margate
# Processing Record 30 of Set 22 | sijua
# Processing Record 31 of Set 22 | brewster
# Processing Record 32 of Set 22 | mpongwe
# Processing Record 33 of Set 22 | samarai
# Processing Record 34 of Set 22 | walvis bay
# Processing Record 35 of Set 22 | gazli
# Processing Record 36 of Set 22 | shingu
# Processing Record 37 of Set 22 | bjornevatn
# Processing Record 38 of Set 22 | prince rupert
# Processing Record 39 of Set 22 | bud
# Processing Record 40 of Set 22 | hami
# Processing Record 41 of Set 22 | verkhoyansk
# Processing Record 42 of Set 22 | selma
# Processing Record 43 of Set 22 | sretensk
# Processing Record 44 of Set 22 | leningradskiy
# Processing Record 45 of Set 22 | shenjiamen
# Processing Record 46 of Set 22 | marzuq
# Processing Record 47 of Set 22 | ostrovnoy
# Processing Record 48 of Set 22 | sapa
# Processing Record 49 of Set 22 | korcula
# Processing Record 50 of Set 22 | akdepe
# Processing Record 1 of Set 23 | pacific grove
# Processing Record 2 of Set 23 | lakes entrance
# Processing Record 3 of Set 23 | kruisfontein
# Processing Record 4 of Set 23 | la orilla
# Processing Record 5 of Set 23 | mao
# Processing Record 6 of Set 23 | dudinka
# Processing Record 7 of Set 23 | pevek
# Processing Record 8 of Set 23 | nioro
# Processing Record 9 of Set 23 | mayumba
# Processing Record 10 of Set 23 | macau
# Processing Record 11 of Set 23 | eureka
# Processing Record 12 of Set 23 | hohhot
# Processing Record 13 of Set 23 | zhigansk
# Processing Record 14 of Set 23 | touros
# Processing Record 15 of Set 23 | nador
# Processing Record 16 of Set 23 | awjilah
# Processing Record 17 of Set 23 | vila velha
# Processing Record 18 of Set 23 | okhotsk
# Processing Record 19 of Set 23 | whitehorse
# Processing Record 20 of Set 23 | el rosario
# Processing Record 21 of Set 23 | saint-francois
# Processing Record 22 of Set 23 | rawson
# Processing Record 23 of Set 23 | mataram
# Processing Record 24 of Set 23 | hofn
# Processing Record 25 of Set 23 | atasu
# Processing Record 26 of Set 23 | pauini
# Processing Record 27 of Set 23 | charters towers
# Processing Record 28 of Set 23 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 23 | wasilla
# Processing Record 30 of Set 23 | labutta
# City not found. Skipping...
# Processing Record 31 of Set 23 | narwar
# Processing Record 32 of Set 23 | college
# Processing Record 33 of Set 23 | savannah bight
# Processing Record 34 of Set 23 | veraval
# Processing Record 35 of Set 23 | preobrazheniye
# Processing Record 36 of Set 23 | ranchpar
# Processing Record 37 of Set 23 | qasigiannguit
# Processing Record 38 of Set 23 | amapa
# Processing Record 39 of Set 23 | falealupo
# City not found. Skipping...
# Processing Record 40 of Set 23 | jackson
# Processing Record 41 of Set 23 | shache
# Processing Record 42 of Set 23 | phu khieo
# City not found. Skipping...
# Processing Record 43 of Set 23 | nacala
# Processing Record 44 of Set 23 | mafeteng
# Processing Record 45 of Set 23 | tomatlan
# Processing Record 46 of Set 23 | buala
# Processing Record 47 of Set 23 | pathein
# Processing Record 48 of Set 23 | pimentel
# Processing Record 49 of Set 23 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 50 of Set 23 | seguela
# Processing Record 1 of Set 24 | riachao
# Processing Record 2 of Set 24 | beyneu
# Processing Record 3 of Set 24 | manggar
# Processing Record 4 of Set 24 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 24 | karlskrona
# Processing Record 6 of Set 24 | puri
# Processing Record 7 of Set 24 | grants pass
# Processing Record 8 of Set 24 | palestina
# Processing Record 9 of Set 24 | jatiroto
# Processing Record 10 of Set 24 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 24 | khagrachari
# City not found. Skipping...
# Processing Record 12 of Set 24 | moose factory
# Processing Record 13 of Set 24 | tarauaca
# Processing Record 14 of Set 24 | xuddur
# Processing Record 15 of Set 24 | tazovskiy
# Processing Record 16 of Set 24 | mbarara
# Processing Record 17 of Set 24 | tshikapa
# Processing Record 18 of Set 24 | celestun
# Processing Record 19 of Set 24 | launceston
# Processing Record 20 of Set 24 | olecko
# Processing Record 21 of Set 24 | ayer itam
# City not found. Skipping...
# Processing Record 22 of Set 24 | sola
# Processing Record 23 of Set 24 | beian
# Processing Record 24 of Set 24 | richmond
# Processing Record 25 of Set 24 | neuruppin
# Processing Record 26 of Set 24 | joshimath
# Processing Record 27 of Set 24 | mandan
# Processing Record 28 of Set 24 | yuci
# Processing Record 29 of Set 24 | tarudant
# City not found. Skipping...
# Processing Record 30 of Set 24 | butembo
# Processing Record 31 of Set 24 | dalianwan
# Processing Record 32 of Set 24 | simao
# Processing Record 33 of Set 24 | trelew
# Processing Record 34 of Set 24 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 24 | liberal
# Processing Record 36 of Set 24 | acapulco
# Processing Record 37 of Set 24 | thibodaux
# Processing Record 38 of Set 24 | orlik
# Processing Record 39 of Set 24 | igarka
# Processing Record 40 of Set 24 | nyrob
# Processing Record 41 of Set 24 | kulhudhuffushi
# Processing Record 42 of Set 24 | wau
# Processing Record 43 of Set 24 | oktyabrskoye
# Processing Record 44 of Set 24 | taoudenni
# Processing Record 45 of Set 24 | illapel
# Processing Record 46 of Set 24 | vallenar
# Processing Record 47 of Set 24 | dingolfing
# Processing Record 48 of Set 24 | talakan
# Processing Record 49 of Set 24 | ustka
# Processing Record 50 of Set 24 | kaset sombun
# Processing Record 1 of Set 25 | isangel
# Processing Record 2 of Set 25 | west plains
# Processing Record 3 of Set 25 | haines junction
# Processing Record 4 of Set 25 | kajaani
# Processing Record 5 of Set 25 | arona
# Processing Record 6 of Set 25 | valentin gomez farias
# Processing Record 7 of Set 25 | warmbad
# Processing Record 8 of Set 25 | agadez
# Processing Record 9 of Set 25 | morganton
# Processing Record 10 of Set 25 | paita
# Processing Record 11 of Set 25 | beira
# Processing Record 12 of Set 25 | ilawe
# Processing Record 13 of Set 25 | sinegorye
# Processing Record 14 of Set 25 | lavrentiya
# Processing Record 15 of Set 25 | porangatu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 560

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Kavieng  -2.57  150.80     85.57        68           2        7.90
# 1        Cherskiy  68.75  161.30     53.74        42          16       17.54
# 2         Rikitea -23.12 -134.97     70.21        57          95       15.39
# 3  Ribeira Grande  38.52  -28.70     67.14        92          78       15.01
# 4       Manokwari  -0.87  134.08     84.25        68          55        6.67
#
#   Country                 Date
# 0      PG  2020-06-23 01:01:44
# 1      RU  2020-06-23 01:01:44
# 2      PF  2020-06-23 01:01:44
# 3      PT  2020-06-23 01:01:44
# 4      ID  2020-06-23 01:01:44

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
